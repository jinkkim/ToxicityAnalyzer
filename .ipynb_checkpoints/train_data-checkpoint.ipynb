# %%
import os
import csv
import pandas as pd

# %%
train_data = os.path.join("data/train.csv")
print(train_data)
# Out:
# data/train.csv

# %%
train_data_df = pd.read_csv(train_data)

train_data_df.head()
# Out:
#       id    target                                       comment_text  \
# 0  59848  0.000000  This is so cool. It's like, 'would you want yo...
# 1  59849  0.000000  Thank you!! This would make my life a lot less...
# 2  59852  0.000000  This is such an urgent design problem; kudos t...
# 3  59855  0.000000  Is this something I'll be able to install on m...
# 4  59856  0.893617               haha you guys are a bunch of losers.
#
#    severe_toxicity  obscene  identity_attack   insult  threat  asian  atheist  \
# 0         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 1         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 2         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 3         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 4         0.021277      0.0         0.021277  0.87234     0.0    0.0      0.0
#
#    ...  article_id    rating  funny  wow  sad  likes  disagree  \
# ...

# %%
# module used to connect Python with MongoDb
import pymongo
import json

# default port is 27017
#mongo_client = pymongo.MongoClient("mongodb://localhost:27017")
mongo_client = pymongo.MongoClient("mongodb+srv//k9sam:1234@toxicity-qbryn.mongodb.net/test?retryWrites=true")


# print success when establish connection
print("success")
# Out:
# success

# %%
# define database in mongoDB
mongo_toxicity_db = mongo_client["toxicity"]

# mongoDB collection name = train_data
mongo_train_data = mongo_moody_db["train_data"]

# insert dataframe row to the collection
records = json.loads(train_data_df.T.to_json()).values()
mongo_train_data.insert(records)
# Out:
# C:\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   if __name__ == '__main__':
# [ObjectId('5cdb27b4c61e2d07b88dc49c'),
#  ObjectId('5cdb27b4c61e2d07b88dc49d'),
#  ObjectId('5cdb27b4c61e2d07b88dc49e'),
#  ObjectId('5cdb27b4c61e2d07b88dc49f'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a0'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a1'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a2'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a3'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a4'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a5'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a6'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a7'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a8'),
#  ObjectId('5cdb27b4c61e2d07b88dc4a9'),
#  ObjectId('5cdb27b4c61e2d07b88dc4aa'),
#  ObjectId('5cdb27b4c61e2d07b88dc4ab'),
#  ObjectId('5cdb27b4c61e2d07b88dc4ac'),
#  ObjectId('5cdb27b4c61e2d07b88dc4ad'),
#  ObjectId('5cdb27b4c61e2d07b88dc4ae'),
# ...
